# %% [markdown]
# <a href="https://colab.research.google.com/github/mukulsingh94868/ML-project/blob/supervisedML/ImageProcessing1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import sys
from google.colab.patches  import cv2_imshow

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
# image name as first argu
data=sys.argv[1]

# %%
# image read
img=cv2.imread('pexels-photo-1108099.jpeg',1)  # loadind image ina

# %%
print(img)
# Out:
# [[[ 56  95  74]
#   [ 56  95  74]
#   [ 57  96  75]
#   ...
#   [ 56  93  73]
#   [ 56  93  73]
#   [ 55  92  72]]
#
#  [[ 56  95  74]
#   [ 56  95  74]
#   [ 57  96  75]
#   ...
#   [ 56  93  73]
#   [ 56  93  73]
#   [ 55  92  72]]
#
#  [[ 56  95  74]
#   [ 57  96  75]
#   [ 57  96  75]
#   ...
#   [ 56  93  73]
#   [ 56  93  73]
#   [ 56  93  73]]
#
#  ...
#
#  [[ 50  84  73]
#   [ 49  83  72]
#   [ 46  79  72]
#   ...
#   [ 49  92 107]
#   [ 51  94 109]
#   [ 53  96 111]]
#
#  [[ 51  85  74]
#   [ 49  83  72]
#   [ 47  80  73]
#   ...
#   [ 46  91 112]
#   [ 51  94 115]
#   [ 52  97 118]]
#
#  [[ 52  86  75]
#   [ 50  84  73]
#   [ 48  81  74]
#   ...
#   [ 44  90 114]
#   [ 49  93 117]
#   [ 51  97 121]]]

# %%
# shape
print(img.shape)
# Out:
# (375, 500, 3)

# %%
# height,width,color channel
# to show the image
cv2_imshow(img)
cv2_imshow(img-50)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7FE1434319E8>
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7FE143431A20>

# %%
cv2_imshow(img+100)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7FE1434319E8>
