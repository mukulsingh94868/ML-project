# %% [markdown]
# <a href="https://colab.research.google.com/github/mukulsingh94868/ML-project/blob/supervisedML/ImageProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches   import cv2_imshow

# %%
# checking versions
cv2.__version__
# Out:
# '3.4.3'

# %%
# images reading
# images name,image property
myimg=np.zeros((512,512))
img=cv2.imread('download.jpg',1)

# %%
# split into BGR
x,y,z=cv2.split(img)

# %%
cv2_imshow(x)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F5011BA1128>

# %%
# to draw a line in image
cv2.line(img,(0,0),(150,160),(0,0,225),3)
cv2.rectangle(img,(50,50),(100,110),(255,0,0),-1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F5011B28358>
